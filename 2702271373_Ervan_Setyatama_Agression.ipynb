# %% [markdown]
# <a href="https://colab.research.google.com/github/Erpan11400/Scientific-Computing-LAB/blob/main/2702271373_Ervan_Setyatama_Agression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Invers Methotd

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

x = np.linspace(0, 1, 101)
y = 1 + x + x * np.random.random(len(x))


A = np.vstack([x, np.ones(len(x))]).T

y = y[:, np.newaxis]

alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[1.45716225]
#  [1.02296411]]
# <ipython-input-57-37f97fcef397>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
plt.figure(figsize = (10,8))
plt.plot(x,y,'b.')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Psuedoinverse Mothod

# %%
pinv = np.linalg.pinv(A)
alpha = pinv.dot(y)
print(alpha)
# Out:
# [[1.45716225]
#  [1.02296411]]

# %% [markdown]
# Numpy.linalg.lstsq

# %%
alpha = np.linalg.lstsq(A,y,rcond = None) [0]
print(alpha)
# Out:
# [[1.45716225]
#  [1.02296411]]

# %% [markdown]
# Optimize.curve_fit from scipy

# %%
x = np.linspace(0,1,101)
y = 1 + x + x * np.random.random(len(x))

def func (x,a,b):
  y = a*x + b
  return y

alpha = optimize.curve_fit(func,xdata = x, ydata = y) [0]
print(alpha)
# Out:
# [1.53986095 1.01477271]
