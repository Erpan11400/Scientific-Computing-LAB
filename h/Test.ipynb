# %% [markdown]
# <a href="https://colab.research.google.com/github/Erpan11400/Scientific-Computing-LAB/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def aha(a,b):
  if a < b - 5:
    status = 'haha'
  elif a > b + 5:
    status = 'hehe'
  else: status = 'off'

  return status

# %%
status = aha(65,75)
print(status)
# Out:
# haha

# %%
status = aha(75,65)
print(status)
# Out:
# hehe

# %%
status = aha(65,63)
print(status)
# Out:
# off

# %%
x = 3
if x > 1 and x < 2:
  y = 2
elif x > 2 and x < 4:
  y = 4
else: y = 0
print(y)
# Out:
# 4

# %%
x = 3
if 1 < x < 2:
  y = 2
elif 2 < x < 4:
  y = 4
else: y = 0
print(y)
# Out:
# 4
